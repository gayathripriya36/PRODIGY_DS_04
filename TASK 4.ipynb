# %%
import pandas as pd

# Sample data creation for demonstration
data = {
    'post': [
        "I love the new product! It's amazing.",
        "This service is terrible. I'm very disappointed.",
        "Great experience! Will definitely recommend.",
        "Not happy with the recent update. It's buggy.",
        "Absolutely fantastic! Exceeded my expectations.",
        "Worst customer service ever. I'm not coming back.",
        "The quality has really improved. Good job!",
        "Terrible! This is the last time I buy from this brand.",
        "I'm so satisfied with my purchase. Excellent!",
        "Very poor performance. Needs improvement."
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the dataset
print(df.head())
# Out:
#                                                post
# 0             I love the new product! It's amazing.
# 1  This service is terrible. I'm very disappointed.
# 2      Great experience! Will definitely recommend.
# 3     Not happy with the recent update. It's buggy.
# 4   Absolutely fantastic! Exceeded my expectations.

# %%
from textblob import TextBlob

# Function to get sentiment polarity
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# Apply the function to the DataFrame
df['sentiment'] = df['post'].apply(get_sentiment)

# Display the updated DataFrame
print(df.head())
# Out:
#                                                post  sentiment
# 0             I love the new product! It's amazing.   0.423485
# 1  This service is terrible. I'm very disappointed.  -0.987500
# 2      Great experience! Will definitely recommend.   0.500000
# 3     Not happy with the recent update. It's buggy.  -0.200000
# 4   Absolutely fantastic! Exceeded my expectations.   0.500000

# %%
pip install TextBlob
# Out:
# ...
#
#   Obtaining dependency information for TextBlob from https://files.pythonhosted.org/packages/02/07/5fd2945356dd839974d3a25de8a142dc37293c21315729a41e775b5f3569/textblob-0.18.0.post0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/626.3 kB 991.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 71.7/626.3 kB 787.7 kB/s eta 0:00:01
#    ---- ---------------------------------- 71.7/626.3 kB 787.7 kB/s eta 0:00:01
#    ------------- -------------------------- 204.8/626.3 kB 1.2 MB/s eta 0:00:01
#    ------------- ------------------------ 215.0/626.3 kB 935.2 kB/s eta 0:00:01
#    ------------------ --------------------- 297.0/626.3 kB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 327.7/626.3 kB 1.0 MB/s eta 0:00:01
#    ------------------------ --------------- 378.9/626.3 kB 1.0 MB/s eta 0:00:01
# ...

# %%
# Function to categorize sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply the categorization function
df['sentiment_category'] = df['sentiment'].apply(categorize_sentiment)

# Display the updated DataFrame
print(df.head())
# Out:
#                                                post  sentiment  \
# 0             I love the new product! It's amazing.   0.423485
# 1  This service is terrible. I'm very disappointed.  -0.987500
# 2      Great experience! Will definitely recommend.   0.500000
# 3     Not happy with the recent update. It's buggy.  -0.200000
# 4   Absolutely fantastic! Exceeded my expectations.   0.500000
#
#   sentiment_category
# 0           Positive
# 1           Negative
# 2           Positive
# 3           Negative
# 4           Positive

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sentiment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='sentiment_category', data=df, palette='viridis')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# Sentiment polarity distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['sentiment'], bins=10, kde=True, color='skyblue')
plt.title('Sentiment Polarity Distribution')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()

# Average sentiment polarity
average_sentiment = df['sentiment'].mean()
print(f"Average Sentiment Polarity: {average_sentiment}")
# Out:
# Average Sentiment Polarity: 0.0003484848484848424
